# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/deep learning/Mid_term")
# Out:
# Mounted at /content/drive

# %%
#Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##1. Introduction
# The company seeks to automate (in real time) the loan qualifying procedure based on information given by customers while filling out an online application form. It is expected that the development of deep learning models that can help the company predict loan approval in accelerating decision-making process for determining whether an applicant is eligible for a loan or not.

# %% [markdown]
# ##2. Data analysis
# These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have given a problem to identify the customers segments, those are eligible for loan amount so that they can specifically target these customers. Here they have provided a partial data set.
#
# We first load the loan data. Please print out the shape of 'loan_data'.

# %%
#Load dataset
loan_data=pd.read_csv('loan.csv')

# start your code here
n_record,n_category= loan_data.shape
# end your code here
print('There are %d records.' % n_record)
print('Every record has %d categories' % n_category)
# Out:
# There are 614 records.
# Every record has 13 categories

# %% [markdown]
# Expected output:
#
# ```
# There are 614 records.
# Every record has 13 categories
# ```
#
# Now, let's print the 1st 20 records of the loan data, and have a better understanding of what the data look like.

# %%
loan_data.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate           NaN
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
# 15             4950                0.0       125.0             360.0
# 16             3596                0.0       100.0             240.0
# 17             3510                0.0        76.0             360.0
# 18             4887                0.0       133.0             360.0
# 19             2600             3500.0       115.0               NaN
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# 5              1.0         Urban           Y
# 6              1.0         Urban           Y
# 7              0.0     Semiurban           N
# 8              1.0         Urban           Y
# 9              1.0     Semiurban           N
# 10             1.0         Urban           Y
# 11             1.0         Urban           Y
# 12             1.0         Urban           Y
# 13             1.0         Rural           N
# 14             1.0         Urban           Y
# 15             1.0         Urban           Y
# 16             NaN         Urban           Y
# 17             0.0         Urban           N
# 18             1.0         Rural           N
# 19             1.0         Urban           Y

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# We can see that there are 13 categories in the records. Please pay close attention to the data. Sometimes, there are `NaN` values. We will need to fix this later. Right now, Let's analyze the categories one by one.

# %% [markdown]
# ###2.1 Loan ID
# Loan ID is our 1st category. However, this category has no relevance to the approval status. Therefore, we will drop this category. Please print out the first 5 records of the 'loan_data' to make sure that the category 'Loan_ID' is dropped. Hint: check cells above to see how we print the first 20 records.

# %%
loan_data = loan_data.drop(['Loan_ID'], axis = 1)

#start your code here
loan_data.head(5)
# end your code here
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %% [markdown]
# Expected output:
# ![alt text](https://drive.google.com/uc?id=1F8Lve6Wx6lYuoMPCNaq_cLEzT1dY9Z__)

# %% [markdown]
# ### 2.2 Gender
# We would like to know among all these 614 records, how many of them are male, how many of them are female, how many of them are null entries.

# %%
gender_count=loan_data.Gender.value_counts(dropna=False) # count different values in 'Gender' category
print(gender_count)
sns.countplot(x="Gender", data=loan_data, palette="hls")
plt.show()

p_male=gender_count['Male']/n_record
p_female=gender_count['Female']/n_record
p_NaN=gender_count[-1]/n_record

print('Percentage of Male: {:.2f}%'.format(p_male*100))
print('Percentage of Female: {:.2f}%'.format(p_female*100))
print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))
# Out:
# Male      489
# Female    112
# NaN        13
# Name: Gender, dtype: int64
# Percentage of Male: 79.64%
# Percentage of Female: 18.24%
# Percentage of missing value: 2.12%

# %% [markdown]
# Conclusion: There are much more male applicants than female applicants. The missing value takes 2.12% of the records, a small portion of the whole records.

# %% [markdown]
# ### 2.3 Married
# Please follow the same idea in section 2.2 to analyze the category 'Married' and make a conclusion at the end of this section.

# %%
# start your code here
married_count = loan_data.Married.value_counts(dropna=False)
print(married_count)
sns.countplot(x="Married",data=loan_data,palette="hls")
plt.show()

p_married = married_count['Yes']/n_record
p_not_married = married_count['No']/n_record
p_NaN = married_count[-1]/n_record

print('Precentage of applicants Married:{:.2f}%'.format(p_married*100))
print('Precentage of applicants Not Married:{:.2f}%'.format(p_not_married*100))
print('Percentage of missing value:{:.2f}%'.format(p_NaN*100))
# end your code here
# Out:
# Yes    398
# No     213
# NaN      3
# Name: Married, dtype: int64
# Precentage of applicants Married:64.82%
# Precentage of applicants Not Married:34.69%
# Percentage of missing value:0.49%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1GbYJ8nHEgGximpRJMJFwQP4bIiP-luPN)
#
# Please make your conclusion here.

# %% [markdown]
# ###2.4 Dependents
#
# Please follow the same idea in section 2.2 to analyze the category 'Dependents' and make a conclusion at the end of this section.

# %%
# start your code here
dependent_count = loan_data.Dependents.value_counts(dropna=False)
print(dependent_count)
sns.countplot(x="Dependents",data=loan_data,palette="hls")
plt.show()

p_zero_dep = dependent_count['0']/n_record
p_one_dep = dependent_count['1']/n_record
p_two_dep = dependent_count['2']/n_record
p_threeplus_dep = dependent_count['3+']/n_record
p_NaN = dependent_count[-1]/n_record

print('Precentage of 0 dependents:{:.2f}%'.format(p_zero_dep*100))
print('Precentage of 1 dependent:{:.2f}%'.format(p_one_dep*100))
print('Precentage of 2 dependents:{:.2f}%'.format(p_two_dep*100))
print('Precentage of 3+ dependents:{:.2f}%'.format(p_threeplus_dep*100))
print('Percentage of missing value:{:.2f}%'.format(p_NaN*100))
# end your code here
# Out:
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: Dependents, dtype: int64
# Precentage of 0 dependents:56.19%
# Precentage of 1 dependent:16.61%
# Precentage of 2 dependents:16.45%
# Precentage of 3+ dependents:8.31%
# Percentage of missing value:2.44%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1T05UzKCRuFpxUY4EJKzOZ-MQgFfSsR0v)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.5 Education
#
# Please follow the same idea in section 2.2 to analyze the category 'Education' and make a conclusion at the end of this section.

# %%
# start your code here
education_count = loan_data.Education.value_counts(dropna=False)
print(education_count)
sns.countplot(x="Education",data=loan_data,palette="hls")
plt.show()

p_grad = education_count['Graduate']/n_record
p_not_grad = education_count['Not Graduate']/n_record
p_NaN = education_count[-1]/n_record

print('Precentage of Graduate:{:.2f}%'.format(p_grad*100))
print('Precentage of Not Graduate:{:.2f}%'.format(p_not_grad*100))
print('Percentage of missing value:{:.2f}%'.format(p_NaN*100))
# end your code here
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# Precentage of Graduate:78.18%
# Precentage of Not Graduate:21.82%
# Percentage of missing value:21.82%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1uAg12JNPRvQCVZd6tPtYfUZH9Qqs4AR5)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.6 Self_Employed
#
# Please follow the same idea in section 2.2 to analyze the category 'Self_Employed' and make a conclusion at the end of this section.

# %%
# start your code here
self_employed_count = loan_data.Self_Employed.value_counts(dropna=False)
print(self_employed_count)
sns.countplot(x="Self_Employed",data=loan_data,palette="hls")
plt.show()

p_SE = self_employed_count['Yes']/n_record
p_not_SE = self_employed_count['No']/n_record
p_NaN = self_employed_count[-1]/n_record

print('Precentage of Self Employed:{:.2f}%'.format(p_SE*100))
print('Precentage of Not Self Employed:{:.2f}%'.format(p_not_SE*100))
print('Percentage of missing value:{:.2f}%'.format(p_NaN*100))
# end your code here
# Out:
# No     500
# Yes     82
# NaN     32
# Name: Self_Employed, dtype: int64
# Precentage of Self Employed:13.36%
# Precentage of Not Self Employed:81.43%
# Percentage of missing value:5.21%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1SLZFuBWQpXL62a9ppu9i8An4WDruJOmi)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.7 Applicant income
# The applicant income has a large range of values, and the previous analysis method doesn't apply well in this case. We will use histogram to characterize the distribution of the income.
#
# From the plot, we can see that the income of most applicants are below $10,000, and are not evenly distributed. Normalization is definitly needed for this category.
#
# Besides, the distribution has a thin but long right tail. We will need to treat the right tail to make the distribution more concentrated.

# %%
sns.histplot(loan_data['ApplicantIncome'])
plt.show()

# %% [markdown]
# ### 2.8 Coapplicant income
# Please use the same technique in Section 2.7 to analyze the distribution of the 'CoapplicantIncome' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['CoapplicantIncome'])
plt.show()
print('We can  see that most of the coapplicants have an income less than $10,000.')
print('Of that group the vast majority does not have an income at all.')
# end your code here
# Out:
# We can  see that most of the coapplicants have an income less than $10,000.
# Of that group the vast majority does not have an income at all.

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1Phqf9WgoHK6OZBuLLWhb8cexvn1bzqye)
#
# Discussion here:

# %% [markdown]
# ### 2.9 Loan amount
#
# Please use the same technique in Section 2.7 to analyze the distribution of the 'LoanAmount' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['LoanAmount'])
plt.show()
print('Most applicants are borrowing just over $100.')
print('A few applicants are borrowings upwards of $500 - $700.')
# end your code here
# Out:
# Most applicants are borrowing just over $100.
# A few applicants are borrowings upwards of $500 - $700.

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1THtXJXErj8rMLcLMVAc1GIsInRajueKG)
#
# Discussion here:

# %% [markdown]
# ### 2.10 Loan_amount_term
#
# Please use the same technique in Section 2.7 to analyze the distribution of the 'Loan_Amount_Term	' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['Loan_Amount_Term'])
plt.show()
print('The loan terms for the majority of the applicants seem to be roughly a full year (360 days).')

# end your code here
# Out:
# The loan terms for the majority of the applicants seem to be roughly a full year (360 days).

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1UTKNr75TQKF626JWvAJJ6ItM_dgw3R2J)
#
# Discussion here:

# %% [markdown]
# ### 2.11 Credit history
#
# Please follow the same technique in section 2.7 to analyze the category 'Credit_History' and give a grief discusion.

# %%
# start your code here
sns.histplot(loan_data['Credit_History'])
plt.show()
print('Most of the applicants have a credit history.')
print('Roughly 100 appplicants do not have a credit history.')
# end your code here
# Out:
# Most of the applicants have a credit history.
# Roughly 100 appplicants do not have a credit history.

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1O03n_ZcFpIsr-lubli-g_IPwL6ZhGpr0)
#
# Discussion here:

# %% [markdown]
# ### 2.12 Property area
#
# Please follow the same technique in section 2.2 to analyze the category 'Property_Area' and give a grief discusion.

# %%
# start your code here
property_area_count = loan_data.Property_Area.value_counts(dropna=False)
print(property_area_count)
sns.countplot(x="Property_Area",data=loan_data,palette="hls")
plt.show()

p_urban = property_area_count['Urban']/n_record
p_rural = property_area_count['Rural']/n_record
p_semiurban = property_area_count['Semiurban']/n_record
p_NaN = property_area_count[-1]/n_record

print('Precentage of Semiurban:{:.2f}%'.format(p_semiurban*100))
print('Precentage of Urban:{:.2f}%'.format(p_urban*100))
print('Precentage of Rural:{:.2f}%'.format(p_rural*100))
print('Percentage of missing value:{:.2f}%'.format(p_NaN*100))

print('')

print('The most prominent property areas amongst the applications are Semiurban.')
print('The second most prominent areas are Urban.')
print('Coming in third are the Rural areas')
# end your code here
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# Precentage of Semiurban:37.95%
# Precentage of Urban:32.90%
# Precentage of Rural:29.15%
# Percentage of missing value:29.15%
#
# The most prominent property areas amongst the applications are Semiurban.
# The second most prominent areas are Urban.
# Coming in third are the Rural areas

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1ZQ0MRWAMe4fFTn9bF-M8ttIVDlJ1kysC)
#
# Discussion here:

# %% [markdown]
# ###2.13 Loan Status
# Please follow the same technique in section 2.2 to analyze the category 'Loan_Status' and give a grief discusion.

# %%
# start your code here
loan_status_count = loan_data.Loan_Status.value_counts(dropna=False)
print(loan_status_count)
sns.countplot(x="Loan_Status",data=loan_data,palette="hls")
plt.show()

p_ls_yes = loan_status_count['Y']/n_record
p_ls_no = loan_status_count['N']/n_record
p_NaN = loan_status_count[-1]/n_record

print('Precentage of YES:{:.2f}%'.format(p_ls_yes*100))
print('Precentage of NO:{:.2f}%'.format(p_ls_no*100))
print('Percentage of missing value:{:.2f}%'.format(p_NaN*100))

print('')

print('Roughly two-thirds of the applicants currently have an active loan.')
# end your code here
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# Precentage of YES:68.73%
# Precentage of NO:31.27%
# Percentage of missing value:31.27%
#
# Roughly two-thirds of the applicants currently have an active loan.

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1KByUcd1F74SAneDWcUgj9_8Vbb-pOGz3)
#
# Discussion here:

# %% [markdown]
# ## 3. Data preprocessing
#
# ### 3.1 Data imputation

# %%
# Checking Null Values.
loan_data.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# There are missing values in Gender, Married, Dependents, Self_Employed, LoanAmount, Loan_Amount_Term, and Credit_History features.
# We will treat the missing values in all the features one by one.
# We can consider these methods to fill the missing values:
#
# * For numerical variables: imputation using mean or median
# * For categorical variables: imputation using mode
#
# There are very few missing values in Gender, Married, Dependents, Credit_History, and Self_Employed features so we can fill them using the mode of the features.
#
# The imputation of 'Gender' is given. Please use the same command to fill the missing values in category 'Married', 'Dependents', 'Self_Employed', and 'Credit_History'.

# %%
loan_data['Gender'].fillna(loan_data['Gender'].mode()[0], inplace=True)
# start your code here
loan_data['Married'].fillna(loan_data['Married'].mode()[0], inplace=True)
loan_data['Dependents'].fillna(loan_data['Dependents'].mode()[0], inplace=True)
loan_data['Self_Employed'].fillna(loan_data['Self_Employed'].mode()[0], inplace=True)
loan_data['Credit_History'].fillna(loan_data['Credit_History'].mode()[0], inplace=True)
# end your code here

# %% [markdown]
# For numerical variables like LoanAmount and Loan_Amount_Term, we fill the missing values with their medians. The imputation of 'Loan_Amount_Term' is given. Please use the same command to fill the missing values in category 'LoanAmount'.

# %%
loan_data['Loan_Amount_Term'].fillna(loan_data['Loan_Amount_Term'].median(),inplace = True)
# start your code here
loan_data['LoanAmount'].fillna(loan_data['LoanAmount'].median(),inplace = True)
# end your code here

# %% [markdown]
# Now, let's print out the data to see whether we fill the missing values with reasonable values. You can compare the table below with the table in the beginning to see the differences.

# %%
loan_data.head(20)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male      No          0      Graduate            No             5849
# 1     Male     Yes          1      Graduate            No             4583
# 2     Male     Yes          0      Graduate           Yes             3000
# 3     Male     Yes          0  Not Graduate            No             2583
# 4     Male      No          0      Graduate            No             6000
# 5     Male     Yes          2      Graduate           Yes             5417
# 6     Male     Yes          0  Not Graduate            No             2333
# 7     Male     Yes         3+      Graduate            No             3036
# 8     Male     Yes          2      Graduate            No             4006
# 9     Male     Yes          1      Graduate            No            12841
# 10    Male     Yes          2      Graduate            No             3200
# 11    Male     Yes          2      Graduate            No             2500
# 12    Male     Yes          2      Graduate            No             3073
# 13    Male      No          0      Graduate            No             1853
# 14    Male     Yes          2      Graduate            No             1299
# 15    Male      No          0      Graduate            No             4950
# 16    Male      No          1  Not Graduate            No             3596
# 17  Female      No          0      Graduate            No             3510
# 18    Male     Yes          0  Not Graduate            No             4887
# 19    Male     Yes          0      Graduate            No             2600
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                 0.0       128.0             360.0             1.0
# 1              1508.0       128.0             360.0             1.0
# 2                 0.0        66.0             360.0             1.0
# 3              2358.0       120.0             360.0             1.0
# 4                 0.0       141.0             360.0             1.0
# 5              4196.0       267.0             360.0             1.0
# 6              1516.0        95.0             360.0             1.0
# 7              2504.0       158.0             360.0             0.0
# 8              1526.0       168.0             360.0             1.0
# 9             10968.0       349.0             360.0             1.0
# 10              700.0        70.0             360.0             1.0
# 11             1840.0       109.0             360.0             1.0
# 12             8106.0       200.0             360.0             1.0
# 13             2840.0       114.0             360.0             1.0
# 14             1086.0        17.0             120.0             1.0
# 15                0.0       125.0             360.0             1.0
# 16                0.0       100.0             240.0             1.0
# 17                0.0        76.0             360.0             0.0
# 18                0.0       133.0             360.0             1.0
# 19             3500.0       115.0             360.0             1.0
#
#    Property_Area Loan_Status
# 0          Urban           Y
# 1          Rural           N
# 2          Urban           Y
# 3          Urban           Y
# 4          Urban           Y
# 5          Urban           Y
# 6          Urban           Y
# 7      Semiurban           N
# 8          Urban           Y
# 9      Semiurban           N
# 10         Urban           Y
# 11         Urban           Y
# 12         Urban           Y
# 13         Rural           N
# 14         Urban           Y
# 15         Urban           Y
# 16         Urban           Y
# 17         Urban           N
# 18         Rural           N
# 19         Urban           Y

# %% [markdown]
# Please check whether all missing values are filled using the command `loan_data.isnull().sum()`. If you have all '0' entries, congratulations! You have finished the data imputation.

# %%
loan_data.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Expected output:
# ```
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# ```

# %% [markdown]
# ### 3.2 Converting categorical values to numbers
#
# Let's first take a look at the data type of the loan data.

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %% [markdown]
# From the information provided above, we see that the data type of 7 categories is object. We need to convert them to numbers to train our model.
#
# * For 'Gender' category, 'Male' is mapped to 0, 'Female' is mapped to 1.
#
# Please use the same technique to do the following conversion.
#
# * For 'Married', 'Self_Employed', and 'Loan_Status' category, please map 'No' to 0 and 'Yes' to 1.
#
# * For 'Dependents' category, please map '0' to 0, '1' to 1, '2' to 2, and '3+' to 3.
#
# * For 'Education' category, please map 'Graduate' to 1 and 'Not Graduate' to 0.
#
# * For 'Property_Area' category, please map 'Rural' to 0, 'Semiurban' to 1, and 'Urban' to 2.

# %%
# Converting the categories into numbers using map function.
loan_data['Gender'] = loan_data['Gender'].map({'Male': 0, 'Female': 1})

# start your code here
loan_data['Married'] = loan_data['Married'].map({'No': 0, 'Yes': 1})
loan_data['Self_Employed'] = loan_data['Self_Employed'].map({'No': 0, 'Yes': 1})
loan_data['Loan_Status'] = loan_data['Loan_Status'].map({'N': 0, 'Y': 1})
loan_data['Dependents'] = loan_data['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})
loan_data['Education'] = loan_data['Education'].map({'Not Graduate': 0, 'Graduate': 1})
loan_data['Property_Area'] = loan_data['Property_Area'].map({'Rural': 0, 'Semiurban': 1, 'Urban': 2})
# end your code here

# %% [markdown]
# Now, let's double check the data types to make sure that we have all numerical entries.

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB

# %% [markdown]
# Expected output:
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB
# ```

# %% [markdown]
# ### 3.3 Right tail treatment
# From section 2.7, 2.8, and 2.9, we see that the income of applicants, coapplicants, and the loan amount have long and thin right tail.
#
# It can be seen that having long and thin right tail often has a significant effect on the mean and standard deviation and hence affecting the distribution. We must take steps to remove the tails from our data sets.
#
# This is called right skewness. One way to remove the skewness is by doing the log transformation. As we take the log transformation, it does not affect the smaller values much but reduces the larger values. So, we get a distribution similar to normal distribution.
# Let’s visualize the effect of log transformation.
#
# Originally, the distribution of applicant income is as below.
#
# ![alt text](https://drive.google.com/uc?id=1UfnWuvx4SV0VLIm5cv0cR1zGteB2g199)
#
# We will apply log transformation to the 'ApplicantIncome' category and recheck the distribution to see the difference.

# %%
epsilon=1
loan_data['ApplicantIncome']=np.log(epsilon+loan_data['ApplicantIncome'])
sns.histplot(loan_data['ApplicantIncome'])
plt.show()

# %% [markdown]
# After the tail treatment, the distribution looks more like a normal distribution. It gives a good base for the next step: data normalization.
#
# Please use the same methods to treat the tails in 'CoapplicantIncome' and 'LoanAmount' category.

# %%
# start your code here
epsilon=1
loan_data['CoapplicantIncome']=np.log(epsilon+loan_data['CoapplicantIncome'])
sns.histplot(loan_data['CoapplicantIncome'])
plt.show()

loan_data['LoanAmount']=np.log(epsilon+loan_data['LoanAmount'])
sns.histplot(loan_data['LoanAmount'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=11JyrjdzswoYkblgYxm8vvD5KssQmxkyw)

# %% [markdown]
# ### 3.4 Other data preprocessing
#
# We emphasized a lot that you will need to preprocess your data before using them to train your model. Now, please think about whether there are other preprocessing that you can do to help you train a good model. If yes, please do it here.

# %%
# start your code here

# end your code here
loan_data.shape
# Out:
# (614, 12)

# %% [markdown]
# ### 3.5 Correlation among different categories
#
# Now let’s look at the correlation between all the numerical variables. We will use the heat map to visualize the correlation. Heatmaps visualize data through variations in coloring. The variables with darker color means their correlation is more.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(loan_data.corr(), vmax=.8, cmap='BuPu',annot=True, fmt='.2g')

# %% [markdown]
# We see a strong correlation between 'Credit_History' and 'Loan_Status', 'LoanAmount' and 'ApplicantIncome', 'CoapplicantIncome' and 'Married', a strong reverse correlation between 'ApplicantIncome' and 'CoapplicantIncom'. When we choose the categories for the training input, these are all elements that need to be considered.

# %% [markdown]
# ### 3.6 Input and output data splitting
#
# We need to predict the 'Loan_Status'. So, our output is 'Loan_Status'. For the input, you can choose as many  relavant categories as you like.
#
# The output data is seperated. As neural network only accept float as the training data set, we use `np.float32` to change the data type to float.
#
# Please choose your input categories using the similar ideas.

# %%
#array = loan_data.values
Y = np.float32(loan_data[['Loan_Status']].values)
# start your code here
X = np.float32(loan_data[['Credit_History']].values)

# end your code here
X.dtype
# Out:
# dtype('float32')

# %% [markdown]
# Expected output:
# ```
# dtype('float32')
# ```

# %% [markdown]
# ### 3.7 Training and testing data splitting
#
# In our lecture, we mentioned that if you have a small dataset (<2000 samples). It is suggested to use 20% of it for testing purpose. It can be easily realized using sklearn library.

# %%
from sklearn import model_selection
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=1234)

# %% [markdown]
# ## 4 Building Neural network
#
# Please use what we learned before to build your neural network. You have the freedome to choose your network structure. Just keep it in mind that the number of neurons in the input layer and the output layer should be the same as the size of your input and output data for each sample. Besides, since this is a binary classification problem, the activation function in the output layer needs to be 'sigmoid' function.

# %%
import tensorflow as tf

# start your code here
model=tf.keras.Sequential([
    #Input layer                      
    tf.keras.layers.Input(shape=(1)), 

    #Start adding hidden layers  
    tf.keras.layers.Dense(x_train.shape[0], activation= 'relu'), # Please set your neuron numbers, activation function and so on. 

    #please feel free to add more hidden layers here. 
     tf.keras.layers.Dense(400, activation= 'relu'),
     tf.keras.layers.Dense(350, activation= 'relu'),
     tf.keras.layers.Dense(300,activation='relu'),
     tf.keras.layers.Dense(250,activation='selu', kernel_regularizer=tf.keras.regularizers.L2(0.01)),
     tf.keras.layers.Dropout(0.01, (250,)),

    # End adding hidden layers 

    #output layer                   
    tf.keras.layers.Dense(y_train.shape[0], activation='sigmoid') # Set how many elements are there in every training output
])
# end your code here
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 491)               982
#
#  dense_1 (Dense)             (None, 400)               196800
#
#  dense_2 (Dense)             (None, 350)               140350
#
#  dense_3 (Dense)             (None, 300)               105300
#
#  dense_4 (Dense)             (None, 250)               75250
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense_5 (Dense)             (None, 491)               123241
#
# =================================================================
# Total params: 641,923
# Trainable params: 641,923
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Compiling and training your neural network
# Please use what you learned before to compile and train your neural network.

# %%
# start your code here
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.005),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, 
    name='sparse_categorical_crossentropy'
),
  # loss. Please change 'None' to some meaningful loss
              # List of metrics t
              metrics=['accuracy'],
                 )

history = model.fit(
    x_train , #  training input data
    y_train, # training output data
    batch_size=10, # how many samples (points) do you want to use to update weights once? 
    epochs=1500 # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)

#end your code here
# Out:
# Epoch 1/1500
# 50/50 [==============================] - 3s 7ms/step - loss: 1.8703 - accuracy: 0.6477
# Epoch 2/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7625 - accuracy: 0.7495
# Epoch 3/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6464 - accuracy: 0.7434
# Epoch 4/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5672 - accuracy: 0.7963
# Epoch 5/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5373 - accuracy: 0.7963
# Epoch 6/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5503 - accuracy: 0.7963
# Epoch 7/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5371 - accuracy: 0.7963
# Epoch 8/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5230 - accuracy: 0.7963
# Epoch 9/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5229 - accuracy: 0.7963
# Epoch 10/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5264 - accuracy: 0.7963
# Epoch 11/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5288 - accuracy: 0.7963
# Epoch 12/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5219 - accuracy: 0.7963
# Epoch 13/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5132 - accuracy: 0.7963
# Epoch 14/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5111 - accuracy: 0.7963
# Epoch 15/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5157 - accuracy: 0.7963
# Epoch 16/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5133 - accuracy: 0.7963
# Epoch 17/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5185 - accuracy: 0.7963
# Epoch 18/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6334 - accuracy: 0.7536
# Epoch 19/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5268 - accuracy: 0.7963
# Epoch 20/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.7862
# Epoch 21/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.7963
# Epoch 22/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5308 - accuracy: 0.7800
# Epoch 23/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5567 - accuracy: 0.7821
# Epoch 24/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5461 - accuracy: 0.7963
# Epoch 25/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5165 - accuracy: 0.7963
# Epoch 26/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5253 - accuracy: 0.7963
# Epoch 27/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5108 - accuracy: 0.7963
# Epoch 28/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.7963
# Epoch 29/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 30/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5131 - accuracy: 0.7963
# Epoch 31/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5146 - accuracy: 0.7963
# Epoch 32/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5095 - accuracy: 0.7963
# Epoch 33/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 34/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 35/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 36/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5166 - accuracy: 0.7963
# Epoch 37/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 38/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 39/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5144 - accuracy: 0.7963
# Epoch 40/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5859 - accuracy: 0.7963
# Epoch 41/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5828 - accuracy: 0.7923
# Epoch 42/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5532 - accuracy: 0.7963
# Epoch 43/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5432 - accuracy: 0.7963
# Epoch 44/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5405 - accuracy: 0.7963
# Epoch 45/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5406 - accuracy: 0.7963
# Epoch 46/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5350 - accuracy: 0.7963
# Epoch 47/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5280 - accuracy: 0.7963
# Epoch 48/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5180 - accuracy: 0.7963
# Epoch 49/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5149 - accuracy: 0.7963
# Epoch 50/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5198 - accuracy: 0.7963
# Epoch 51/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5222 - accuracy: 0.7963
# Epoch 52/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5133 - accuracy: 0.7963
# Epoch 53/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5156 - accuracy: 0.7963
# Epoch 54/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5175 - accuracy: 0.7963
# Epoch 55/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5114 - accuracy: 0.7963
# Epoch 56/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.7963
# Epoch 57/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5112 - accuracy: 0.7963
# Epoch 58/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5145 - accuracy: 0.7963
# Epoch 59/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5057 - accuracy: 0.7963
# Epoch 60/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.7963
# Epoch 61/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5125 - accuracy: 0.7963
# Epoch 62/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5163 - accuracy: 0.7963
# Epoch 63/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5119 - accuracy: 0.7963
# Epoch 64/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5107 - accuracy: 0.7963
# Epoch 65/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5092 - accuracy: 0.7963
# Epoch 66/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5077 - accuracy: 0.7963
# Epoch 67/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 68/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 69/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5077 - accuracy: 0.7963
# Epoch 70/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 71/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 72/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 73/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5063 - accuracy: 0.7963
# Epoch 74/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5102 - accuracy: 0.7963
# Epoch 75/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5097 - accuracy: 0.7963
# Epoch 76/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 77/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 78/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5150 - accuracy: 0.7963
# Epoch 79/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 80/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 81/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 82/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 83/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 84/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5206 - accuracy: 0.7963
# Epoch 85/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5102 - accuracy: 0.7963
# Epoch 86/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5133 - accuracy: 0.7963
# Epoch 87/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 88/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5085 - accuracy: 0.7963
# Epoch 89/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5095 - accuracy: 0.7963
# Epoch 90/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 91/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5090 - accuracy: 0.7963
# Epoch 92/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5097 - accuracy: 0.7963
# Epoch 93/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7963
# Epoch 94/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5092 - accuracy: 0.7963
# Epoch 95/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 96/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5114 - accuracy: 0.7963
# Epoch 97/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 98/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5084 - accuracy: 0.7963
# Epoch 99/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5134 - accuracy: 0.7963
# Epoch 100/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 101/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5107 - accuracy: 0.7963
# Epoch 102/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.7963
# Epoch 103/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5084 - accuracy: 0.7963
# Epoch 104/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 105/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 106/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 107/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5105 - accuracy: 0.7963
# Epoch 108/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 109/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5221 - accuracy: 0.7963
# Epoch 110/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 111/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5089 - accuracy: 0.7963
# Epoch 112/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 113/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 114/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 115/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 116/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5223 - accuracy: 0.7943
# Epoch 117/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5097 - accuracy: 0.7963
# Epoch 118/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5117 - accuracy: 0.7963
# Epoch 119/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5186 - accuracy: 0.7963
# Epoch 120/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 121/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7963
# Epoch 122/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 123/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.7963
# Epoch 124/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5201 - accuracy: 0.7963
# Epoch 125/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 0.7963
# Epoch 126/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5124 - accuracy: 0.7963
# Epoch 127/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.7963
# Epoch 128/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 129/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5051 - accuracy: 0.7963
# Epoch 130/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5100 - accuracy: 0.7963
# Epoch 131/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5057 - accuracy: 0.7963
# Epoch 132/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5106 - accuracy: 0.7862
# Epoch 133/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5447 - accuracy: 0.7963
# Epoch 134/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5184 - accuracy: 0.7963
# Epoch 135/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5104 - accuracy: 0.7963
# Epoch 136/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 137/1500
# 50/50 [==============================] - 0s 4ms/step - loss: 0.5086 - accuracy: 0.7963
# Epoch 138/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5061 - accuracy: 0.7963
# Epoch 139/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 140/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7963
# Epoch 141/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5051 - accuracy: 0.7963
# Epoch 142/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 143/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 144/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 145/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5130 - accuracy: 0.7963
# Epoch 146/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 147/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5137 - accuracy: 0.7963
# Epoch 148/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5102 - accuracy: 0.7963
# Epoch 149/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 150/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7963
# Epoch 151/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 152/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 153/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 154/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5165 - accuracy: 0.7963
# Epoch 155/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5078 - accuracy: 0.7963
# Epoch 156/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5200 - accuracy: 0.7963
# Epoch 157/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7963
# Epoch 158/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 159/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 160/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7963
# Epoch 161/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5050 - accuracy: 0.7963
# Epoch 162/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 163/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5061 - accuracy: 0.7963
# Epoch 164/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5093 - accuracy: 0.7963
# Epoch 165/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 166/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 167/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5113 - accuracy: 0.7963
# Epoch 168/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5128 - accuracy: 0.7963
# Epoch 169/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.7963
# Epoch 170/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 171/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 172/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 173/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7963
# Epoch 174/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7963
# Epoch 175/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5057 - accuracy: 0.7963
# Epoch 176/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 177/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5036 - accuracy: 0.7963
# Epoch 178/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5051 - accuracy: 0.7963
# Epoch 179/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 180/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5084 - accuracy: 0.7963
# Epoch 181/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 182/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.7963
# Epoch 183/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 184/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.7963
# Epoch 185/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5063 - accuracy: 0.7963
# Epoch 186/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 187/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 188/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 189/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5044 - accuracy: 0.7963
# Epoch 190/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5023 - accuracy: 0.7963
# Epoch 191/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 192/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5088 - accuracy: 0.7963
# Epoch 193/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 194/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5121 - accuracy: 0.7963
# Epoch 195/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 196/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5043 - accuracy: 0.7963
# Epoch 197/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5127 - accuracy: 0.7963
# Epoch 198/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5171 - accuracy: 0.7963
# Epoch 199/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 200/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 201/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5127 - accuracy: 0.7963
# Epoch 202/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7923
# Epoch 203/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 204/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 205/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 206/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5133 - accuracy: 0.7963
# Epoch 207/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5164 - accuracy: 0.7963
# Epoch 208/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5130 - accuracy: 0.7963
# Epoch 209/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5100 - accuracy: 0.7963
# Epoch 210/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5210 - accuracy: 0.7963
# Epoch 211/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5144 - accuracy: 0.7963
# Epoch 212/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5160 - accuracy: 0.7963
# Epoch 213/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5092 - accuracy: 0.7963
# Epoch 214/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 215/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 216/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 217/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 218/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 219/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 220/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5037 - accuracy: 0.7963
# Epoch 221/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 222/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.7963
# Epoch 223/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 224/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7963
# Epoch 225/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 226/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 227/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5116 - accuracy: 0.7963
# Epoch 228/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 229/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.7963
# Epoch 230/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 231/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 232/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5058 - accuracy: 0.7963
# Epoch 233/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 234/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 235/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7963
# Epoch 236/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 237/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 238/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 239/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5020 - accuracy: 0.7963
# Epoch 240/1500
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5044 - accuracy: 0.7963
# Epoch 241/1500
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5050 - accuracy: 0.7963
# Epoch 242/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 243/1500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 244/1500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5044 - accuracy: 0.7963
# Epoch 245/1500
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 246/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 247/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 248/1500
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5096 - accuracy: 0.7963
# Epoch 249/1500
# 50/50 [==============================] - 0s 8ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 250/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5015 - accuracy: 0.7963
# Epoch 251/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 252/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 253/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5133 - accuracy: 0.7963
# Epoch 254/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 255/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.7963
# Epoch 256/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 257/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5107 - accuracy: 0.7963
# Epoch 258/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5086 - accuracy: 0.7963
# Epoch 259/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5185 - accuracy: 0.7963
# Epoch 260/1500
# 50/50 [==============================] - 0s 10ms/step - loss: 0.5149 - accuracy: 0.7963
# Epoch 261/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5097 - accuracy: 0.7963
# Epoch 262/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5132 - accuracy: 0.7963
# Epoch 263/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5132 - accuracy: 0.7963
# Epoch 264/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5093 - accuracy: 0.7963
# Epoch 265/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 266/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 267/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 268/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 269/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5036 - accuracy: 0.7963
# Epoch 270/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5040 - accuracy: 0.7963
# Epoch 271/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 272/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 273/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.7963
# Epoch 274/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 275/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7963
# Epoch 276/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 277/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5058 - accuracy: 0.7963
# Epoch 278/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 279/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5025 - accuracy: 0.7963
# Epoch 280/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5092 - accuracy: 0.7963
# Epoch 281/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7902
# Epoch 282/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.7963
# Epoch 283/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7963
# Epoch 284/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5086 - accuracy: 0.7963
# Epoch 285/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 286/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.7963
# Epoch 287/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7963
# Epoch 288/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5155 - accuracy: 0.7963
# Epoch 289/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5085 - accuracy: 0.7963
# Epoch 290/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 291/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5047 - accuracy: 0.7963
# Epoch 292/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 293/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5063 - accuracy: 0.7963
# Epoch 294/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 295/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 296/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5032 - accuracy: 0.7963
# Epoch 297/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5104 - accuracy: 0.7963
# Epoch 298/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5098 - accuracy: 0.7963
# Epoch 299/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 300/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 301/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 0.7963
# Epoch 302/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 303/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 304/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5036 - accuracy: 0.7963
# Epoch 305/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 306/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 307/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5047 - accuracy: 0.7963
# Epoch 308/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.7963
# Epoch 309/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5153 - accuracy: 0.7963
# Epoch 310/1500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5114 - accuracy: 0.7963
# Epoch 311/1500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5078 - accuracy: 0.7963
# Epoch 312/1500
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5061 - accuracy: 0.7963
# Epoch 313/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 314/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5236 - accuracy: 0.7963
# Epoch 315/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5376 - accuracy: 0.7963
# Epoch 316/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5174 - accuracy: 0.7963
# Epoch 317/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5098 - accuracy: 0.7963
# Epoch 318/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 319/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 320/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5135 - accuracy: 0.7963
# Epoch 321/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.7963
# Epoch 322/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 323/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5093 - accuracy: 0.7963
# Epoch 324/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5063 - accuracy: 0.7963
# Epoch 325/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5100 - accuracy: 0.7963
# Epoch 326/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5128 - accuracy: 0.7963
# Epoch 327/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5171 - accuracy: 0.7963
# Epoch 328/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 329/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5097 - accuracy: 0.7963
# Epoch 330/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 331/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5096 - accuracy: 0.7963
# Epoch 332/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 333/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5134 - accuracy: 0.7963
# Epoch 334/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 335/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 336/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 337/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5126 - accuracy: 0.7963
# Epoch 338/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5085 - accuracy: 0.7963
# Epoch 339/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5095 - accuracy: 0.7963
# Epoch 340/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 341/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5043 - accuracy: 0.7963
# Epoch 342/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5030 - accuracy: 0.7963
# Epoch 343/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 344/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5115 - accuracy: 0.7963
# Epoch 345/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 0.7963
# Epoch 346/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5110 - accuracy: 0.7963
# Epoch 347/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 348/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 349/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 350/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 0.7963
# Epoch 351/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5237 - accuracy: 0.7963
# Epoch 352/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5084 - accuracy: 0.7963
# Epoch 353/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 354/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5146 - accuracy: 0.7963
# Epoch 355/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5115 - accuracy: 0.7963
# Epoch 356/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5116 - accuracy: 0.7963
# Epoch 357/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5089 - accuracy: 0.7963
# Epoch 358/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 359/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5034 - accuracy: 0.7963
# Epoch 360/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5117 - accuracy: 0.7963
# Epoch 361/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5063 - accuracy: 0.7963
# Epoch 362/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 363/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 364/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 365/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 366/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 367/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 368/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5180 - accuracy: 0.7923
# Epoch 369/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5141 - accuracy: 0.7963
# Epoch 370/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5124 - accuracy: 0.7963
# Epoch 371/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7963
# Epoch 372/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5042 - accuracy: 0.7963
# Epoch 373/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5063 - accuracy: 0.7963
# Epoch 374/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 375/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5078 - accuracy: 0.7963
# Epoch 376/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5047 - accuracy: 0.7963
# Epoch 377/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 378/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5022 - accuracy: 0.7963
# Epoch 379/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 380/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5027 - accuracy: 0.7963
# Epoch 381/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 382/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5105 - accuracy: 0.7963
# Epoch 383/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 384/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.7963
# Epoch 385/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 386/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 387/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 388/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 389/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.7963
# Epoch 390/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 391/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.7963
# Epoch 392/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5123 - accuracy: 0.7963
# Epoch 393/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 394/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5057 - accuracy: 0.7963
# Epoch 395/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5086 - accuracy: 0.7963
# Epoch 396/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5057 - accuracy: 0.7963
# Epoch 397/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 398/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5030 - accuracy: 0.7963
# Epoch 399/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.7963
# Epoch 400/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5021 - accuracy: 0.7963
# Epoch 401/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 402/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 403/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5078 - accuracy: 0.7963
# Epoch 404/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 405/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.7963
# Epoch 406/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5107 - accuracy: 0.7902
# Epoch 407/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5135 - accuracy: 0.7963
# Epoch 408/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5110 - accuracy: 0.7963
# Epoch 409/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5105 - accuracy: 0.7963
# Epoch 410/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7963
# Epoch 411/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5159 - accuracy: 0.7963
# Epoch 412/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5096 - accuracy: 0.7963
# Epoch 413/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 414/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5047 - accuracy: 0.7963
# Epoch 415/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 416/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5043 - accuracy: 0.7963
# Epoch 417/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5108 - accuracy: 0.7963
# Epoch 418/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 419/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5089 - accuracy: 0.7963
# Epoch 420/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5106 - accuracy: 0.7963
# Epoch 421/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 422/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5003 - accuracy: 0.7963
# Epoch 423/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 424/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5123 - accuracy: 0.7963
# Epoch 425/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7963
# Epoch 426/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 427/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5136 - accuracy: 0.7963
# Epoch 428/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 429/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.7963
# Epoch 430/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5061 - accuracy: 0.7963
# Epoch 431/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 432/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 433/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 434/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5050 - accuracy: 0.7963
# Epoch 435/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.7963
# Epoch 436/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7963
# Epoch 437/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 438/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5061 - accuracy: 0.7963
# Epoch 439/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 440/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 441/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5028 - accuracy: 0.7963
# Epoch 442/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5032 - accuracy: 0.7963
# Epoch 443/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 444/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7963
# Epoch 445/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5098 - accuracy: 0.7963
# Epoch 446/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.7963
# Epoch 447/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5117 - accuracy: 0.7963
# Epoch 448/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5040 - accuracy: 0.7963
# Epoch 449/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 450/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7963
# Epoch 451/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5106 - accuracy: 0.7963
# Epoch 452/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5084 - accuracy: 0.7963
# Epoch 453/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 454/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.7963
# Epoch 455/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.7963
# Epoch 456/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5034 - accuracy: 0.7963
# Epoch 457/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 458/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5096 - accuracy: 0.7963
# Epoch 459/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5099 - accuracy: 0.7963
# Epoch 460/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5101 - accuracy: 0.7963
# Epoch 461/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 462/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 463/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 464/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5062 - accuracy: 0.7963
# Epoch 465/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5095 - accuracy: 0.7963
# Epoch 466/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 467/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5021 - accuracy: 0.7963
# Epoch 468/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5185 - accuracy: 0.7963
# Epoch 469/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5114 - accuracy: 0.7963
# Epoch 470/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 471/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5040 - accuracy: 0.7963
# Epoch 472/1500
# ...
# Epoch 1346/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 1347/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5044 - accuracy: 0.7963
# Epoch 1348/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.7963
# Epoch 1349/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5193 - accuracy: 0.7963
# Epoch 1350/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7963
# Epoch 1351/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5131 - accuracy: 0.7963
# Epoch 1352/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5121 - accuracy: 0.7963
# Epoch 1353/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5073 - accuracy: 0.7963
# Epoch 1354/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 1355/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 1356/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5044 - accuracy: 0.7963
# Epoch 1357/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5031 - accuracy: 0.7963
# Epoch 1358/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5009 - accuracy: 0.7963
# Epoch 1359/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 1360/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 1361/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5074 - accuracy: 0.7963
# Epoch 1362/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 1363/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 1364/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5119 - accuracy: 0.7963
# Epoch 1365/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 1366/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5103 - accuracy: 0.7963
# Epoch 1367/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5029 - accuracy: 0.7963
# Epoch 1368/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5051 - accuracy: 0.7963
# Epoch 1369/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 1370/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5088 - accuracy: 0.7963
# Epoch 1371/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 1372/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 1373/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 1374/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5046 - accuracy: 0.7963
# Epoch 1375/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5036 - accuracy: 0.7963
# Epoch 1376/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 1377/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7963
# Epoch 1378/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 1379/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7963
# Epoch 1380/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5058 - accuracy: 0.7963
# Epoch 1381/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5072 - accuracy: 0.7963
# Epoch 1382/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 1383/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5160 - accuracy: 0.7963
# Epoch 1384/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 1385/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5133 - accuracy: 0.7963
# Epoch 1386/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5043 - accuracy: 0.7963
# Epoch 1387/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 1388/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5076 - accuracy: 0.7963
# Epoch 1389/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5071 - accuracy: 0.7963
# Epoch 1390/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5036 - accuracy: 0.7963
# Epoch 1391/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 1392/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5182 - accuracy: 0.7963
# Epoch 1393/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5207 - accuracy: 0.7963
# Epoch 1394/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.7963
# Epoch 1395/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 1396/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5044 - accuracy: 0.7963
# Epoch 1397/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5102 - accuracy: 0.7963
# Epoch 1398/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5089 - accuracy: 0.7963
# Epoch 1399/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5151 - accuracy: 0.7963
# Epoch 1400/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5083 - accuracy: 0.7963
# Epoch 1401/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5092 - accuracy: 0.7963
# Epoch 1402/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5015 - accuracy: 0.7963
# Epoch 1403/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 1404/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.7963
# Epoch 1405/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5070 - accuracy: 0.7963
# Epoch 1406/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5079 - accuracy: 0.7963
# Epoch 1407/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5051 - accuracy: 0.7963
# Epoch 1408/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 1409/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5042 - accuracy: 0.7963
# Epoch 1410/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 1411/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 1412/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 1413/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 1414/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 1415/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1416/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1417/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5020 - accuracy: 0.7963
# Epoch 1418/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4993 - accuracy: 0.7963
# Epoch 1419/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5127 - accuracy: 0.7963
# Epoch 1420/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5096 - accuracy: 0.7963
# Epoch 1421/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 1422/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5089 - accuracy: 0.7963
# Epoch 1423/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5064 - accuracy: 0.7963
# Epoch 1424/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 1425/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1426/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5078 - accuracy: 0.7963
# Epoch 1427/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1428/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 1429/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5095 - accuracy: 0.7963
# Epoch 1430/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 1431/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5082 - accuracy: 0.7963
# Epoch 1432/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5080 - accuracy: 0.7963
# Epoch 1433/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 1434/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 1435/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5040 - accuracy: 0.7963
# Epoch 1436/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5085 - accuracy: 0.7963
# Epoch 1437/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 1438/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5061 - accuracy: 0.7963
# Epoch 1439/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5116 - accuracy: 0.7963
# Epoch 1440/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5050 - accuracy: 0.7963
# Epoch 1441/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5040 - accuracy: 0.7963
# Epoch 1442/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5031 - accuracy: 0.7963
# Epoch 1443/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5052 - accuracy: 0.7963
# Epoch 1444/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5089 - accuracy: 0.7963
# Epoch 1445/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 1446/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5110 - accuracy: 0.7963
# Epoch 1447/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5156 - accuracy: 0.7963
# Epoch 1448/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5136 - accuracy: 0.7963
# Epoch 1449/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5025 - accuracy: 0.7963
# Epoch 1450/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5125 - accuracy: 0.7963
# Epoch 1451/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5130 - accuracy: 0.7963
# Epoch 1452/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5034 - accuracy: 0.7963
# Epoch 1453/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5043 - accuracy: 0.7963
# Epoch 1454/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5026 - accuracy: 0.7963
# Epoch 1455/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 1456/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1457/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5077 - accuracy: 0.7963
# Epoch 1458/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5065 - accuracy: 0.7963
# Epoch 1459/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5038 - accuracy: 0.7963
# Epoch 1460/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5037 - accuracy: 0.7963
# Epoch 1461/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5037 - accuracy: 0.7963
# Epoch 1462/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5042 - accuracy: 0.7963
# Epoch 1463/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4999 - accuracy: 0.7963
# Epoch 1464/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5031 - accuracy: 0.7963
# Epoch 1465/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5059 - accuracy: 0.7963
# Epoch 1466/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5102 - accuracy: 0.7923
# Epoch 1467/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5107 - accuracy: 0.7963
# Epoch 1468/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5091 - accuracy: 0.7963
# Epoch 1469/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5115 - accuracy: 0.7963
# Epoch 1470/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 1471/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5068 - accuracy: 0.7963
# Epoch 1472/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 1473/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5067 - accuracy: 0.7963
# Epoch 1474/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1475/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5035 - accuracy: 0.7963
# Epoch 1476/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5042 - accuracy: 0.7963
# Epoch 1477/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 1478/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7963
# Epoch 1479/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5057 - accuracy: 0.7963
# Epoch 1480/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5162 - accuracy: 0.7963
# Epoch 1481/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 1482/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 1483/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 1484/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5114 - accuracy: 0.7963
# Epoch 1485/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5056 - accuracy: 0.7963
# Epoch 1486/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5051 - accuracy: 0.7963
# Epoch 1487/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7963
# Epoch 1488/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5033 - accuracy: 0.7963
# Epoch 1489/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5042 - accuracy: 0.7963
# Epoch 1490/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.7963
# Epoch 1491/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 1492/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5041 - accuracy: 0.7963
# Epoch 1493/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 1494/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5053 - accuracy: 0.7963
# Epoch 1495/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5035 - accuracy: 0.7963
# Epoch 1496/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5045 - accuracy: 0.7963
# Epoch 1497/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5048 - accuracy: 0.7963
# Epoch 1498/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5069 - accuracy: 0.7963
# Epoch 1499/1500
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5088 - accuracy: 0.7963
# Epoch 1500/1500
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5090 - accuracy: 0.7963

# %% [markdown]
# Let's take a look at the training history. You probably will need to adjust the parameters like learning rate, batch size, epochs, or even your NN structure.

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
model.evaluate(x_test,y_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4005 - accuracy: 0.8618
# [0.40053248405456543, 0.8617886304855347]

# %% [markdown]
# After several adjustion, the results may be still unsatisfying. In this case you will need to take a closer look at your prediction and the true value to see where the problems are. Please manually examine what the mistakes are, and use the technique we learned in the most recent 2 weeks to make some synthetic data to help improve your accuracy in Section 3.4. As a reference, the best accuracy that I can find online using NN is 80%. I was able to improve it to 82.5%. See how accurate you can achieve.

# %%
# Getting predictions for the test set
output = model.predict(x_test)
threshold=0.5
y_pred = np.where(output>=threshold,1,0)
print((y_pred==y_test).sum()/len(y_test))
# Getting accuracy score
for i in range(len(x_test)):
  if y_pred[i,:]<y_test[i,:]:
    print(y_test[i,:],y_pred[i,:],output[i,:], x_test[i,:])
# Out:
# 156.0487804878049
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-6d3ccc0fdfa5> in <module>()
#       6 # Getting accuracy score
#       7 for i in range(len(x_test)):
# ----> 8   if y_pred[i,:]<y_test[i,:]:
#       9     print(y_test[i,:],y_pred[i,:],output[i,:], x_test[i,:])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
